# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from __future__ import division
# %matplotlib inline

# %%
oo = pd.read_csv('all_rankings.csv')
oo.head()
# Out:
#      year      PCT team   PCT           PPG team   PPG      OPPG team  OPPG  \
# 0  2017.0       Gonzaga  94.9        The Citadel  89.8       Virginia  56.4
# 1  2017.0     Villanova  88.9               UCLA  89.8   Saint Mary's  57.5
# 2  2017.0       Arizona  86.5      Central Mich.  88.3            SMU  60.0
# 3  2017.0  Middle Tenn.  86.1  Purdue Fort Wayne  86.9  Saint Peter's  60.8
# 4  2017.0          UCLA  86.1       Oklahoma St.  85.7   Old Dominion  61.2
#
#         SPG team   SPG        APG team  ...        FTP team   FTP  \
# 0  West Virginia  10.0            UCLA  ...      Notre Dame  80.0
# 1   Portland St.   9.9          Purdue  ...   Central Mich.  79.1
# 2        Fordham   9.8        Lipscomb  ...       Villanova  79.0
# 3  Eastern Mich.   9.6  North Carolina  ...    Oklahoma St.  78.9
# 4     Holy Cross   9.4            Iowa  ...          Mercer  78.2
#
#        SCMG team  SCMG         RPI team    RPI            SOS team    SOS  \
# 0        Gonzaga  21.1  North Carolina   0.668      North Carolina  0.607
# 1    Wichita St.  18.6         Kentucky  0.658  Vanderbilt (19-16)  0.606
# 2  West Virginia  14.8           Kansas  0.656   Louisville (25-9)  0.604
# 3   Saint Mary's  14.6        Villanova  0.655       Baylor (26-8)  0.601
# 4      Villanova  14.5          Arizona  0.652    Virginia (23-11)  0.600
#
#              ID team    ID
# 0  Abilene Christian  1101
# 1          Air Force  1102
# 2              Akron  1103
# 3            Alabama  1104
# 4        Alabama A&M  1105
#
# [5 rows x 21 columns]

# %%
oo = oo.fillna('no data')
oo = oo.set_index('year')
oo
# Out:
#                      PCT team      PCT              PPG team      PPG  \
# year
# 2017.0                Gonzaga     94.9           The Citadel     89.8
# 2017.0              Villanova     88.9                  UCLA     89.8
# 2017.0                Arizona     86.5         Central Mich.     88.3
# 2017.0           Middle Tenn.     86.1     Purdue Fort Wayne     86.9
# 2017.0                   UCLA     86.1          Oklahoma St.     85.7
# 2017.0            Wichita St.     86.1          Savannah St.     85.7
# 2017.0                 Kansas     86.1              Marshall     85.6
# 2017.0                    SMU     85.7          Portland St.     85.3
# 2017.0           Saint Mary's     85.3              Lipscomb       85
# 2017.0                 Oregon     84.6              Kentucky     84.9
# 2017.0               Kentucky     84.2                  UNCW     84.8
# 2017.0             Cincinnati     83.3        North Carolina     84.4
# 2017.0                   UNCW     82.9                 Omaha     83.9
# 2017.0                Vermont     82.9                Kansas     83.2
# 2017.0         North Carolina     82.5           Wake Forest     82.8
# 2017.0         New Mexico St.     82.4               Gonzaga     82.6
# 2017.0                 Nevada       80             Marquette     82.2
# 2017.0           Illinois St.       80           Florida St.     82.1
# 2017.0               Monmouth     79.4             Louisiana     81.9
# 2017.0               Winthrop     78.8             Creighton     81.8
# 2017.0                 Purdue     77.1        William & Mary     81.7
# 2017.0                 Baylor     77.1                  Rice     81.5
# 2017.0                   ETSU     77.1         West Virginia     81.5
# 2017.0                Belmont     76.7              Monmouth     81.2
# 2017.0              Princeton     76.7                  UMBC     81.1
# 2017.0                   FGCU     76.5           Wichita St.       81
# 2017.0                   Duke     75.7                  Duke     80.8
# 2017.0          West Virginia     75.7              Iowa St.     80.8
# 2017.0                  Akron       75                   BYU     80.6
# 2017.0           UT Arlington       75          North Dakota     80.6
# ...                       ...      ...                   ...      ...
# 2017.0      Central Conn. St.     20.7            Oregon St.     63.2
# 2017.0               Longwood       20     Central Conn. St.       63
# 2017.0                   SIUE       20        Southern Miss.       63
# 2017.0                    VMI       20  St. Francis Brooklyn       62
# 2017.0                 Tulane     19.4                   UNI     61.8
# 2017.0            Chicago St.     18.8       Ark.-Pine Bluff     61.8
# 2017.0          Southern Utah     18.2           Alabama A&M     61.7
# 2017.0           Presbyterian     16.7              American     61.5
# 2017.0              Idaho St.     16.1         Western Caro.     61.4
# 2017.0             Oregon St.     15.6           Saint Louis     61.4
# 2017.0   St. Francis Brooklyn     12.9          Presbyterian     61.2
# 2017.0               N.C. A&T      9.4      UC Santa Barbara     60.8
# 2017.0            Alabama A&M      6.9            Holy Cross     60.4
# no data               no data  no data               no data  no data
# no data               no data  no data               no data  no data
# no data               no data  no data               no data  no data
# no data               no data  no data               no data  no data
# no data               no data  no data               no data  no data
# no data               no data  no data               no data  no data
# no data               no data  no data               no data  no data
# no data               no data  no data               no data  no data
# no data               no data  no data               no data  no data
# no data               no data  no data               no data  no data
# no data               no data  no data               no data  no data
# no data               no data  no data               no data  no data
# no data               no data  no data               no data  no data
# no data               no data  no data               no data  no data
# no data               no data  no data               no data  no data
# no data               no data  no data               no data  no data
# no data               no data  no data               no data  no data
#
#                   OPPG team     OPPG            SPG team      SPG  \
# year
# 2017.0             Virginia     56.4       West Virginia       10
# 2017.0         Saint Mary's     57.5        Portland St.      9.9
# 2017.0                  SMU       60             Fordham      9.8
# 2017.0        Saint Peter's     60.8       Eastern Mich.      9.6
# 2017.0         Old Dominion     61.2          Holy Cross      9.4
# 2017.0                  UCF     61.2  A&M-Corpus Christi      9.4
# 2017.0         Illinois St.     61.3         The Citadel      9.3
# 2017.0           Cincinnati     61.3       UNC Asheville      9.3
# 2017.0            Princeton     61.4           Grambling      8.8
# 2017.0              Gonzaga     61.5        Gardner-Webb      8.8
# 2017.0              Vermont     62.1     Ark.-Pine Bluff      8.7
# 2017.0           Holy Cross     62.1          Fresno St.      8.4
# 2017.0            Wisconsin     62.4                ETSU      8.4
# 2017.0          Wichita St.     62.4           Boston U.      8.3
# 2017.0        San Diego St.     62.5        Prairie View      8.3
# 2017.0            Villanova     62.7               Omaha      8.2
# 2017.0            Texas St.     62.7     CSU Bakersfield      8.2
# 2017.0           California     63.4            Syracuse      8.1
# 2017.0              Liberty     63.4        Jacksonville        8
# 2017.0         N.C. Central     63.5    Lamar University        8
# 2017.0               Baylor     63.7       Robert Morris      7.9
# 2017.0      CSU Bakersfield     63.9         New Orleans      7.9
# 2017.0         Middle Tenn.     63.9        North Dakota      7.8
# 2017.0           Miami (FL)     64.1             Oakland      7.8
# 2017.0                 Navy     64.2        Savannah St.      7.8
# 2017.0                  UNI     64.4      South Carolina      7.8
# 2017.0   Col. of Charleston     64.6              Dayton      7.8
# 2017.0              Alabama     64.7         Chattanooga      7.8
# 2017.0            UC Irvine     64.8            Iowa St.      7.8
# 2017.0              Houston     64.9           Green Bay      7.8
# ...                     ...      ...                 ...      ...
# 2017.0                  LSU       83        Michigan St.      4.3
# 2017.0                UTRGV     83.3             Pacific      4.2
# 2017.0     Mississippi Val.     83.3      Washington St.      4.2
# 2017.0           Quinnipiac     83.3        Saint Mary's      4.2
# 2017.0                Omaha     83.5          Vanderbilt      4.2
# 2017.0          Austin Peay     83.8              Mercer      4.2
# 2017.0             Marshall       84       New Hampshire        4
# 2017.0         Central Ark.     84.1                 UCF        4
# 2017.0        Detroit Mercy     84.8              Toledo        4
# 2017.0        Southern Utah     85.3       Virginia Tech        4
# 2017.0        Central Mich.     87.7           San Diego      3.9
# 2017.0         Savannah St.     91.9          Pittsburgh      3.8
# 2017.0          The Citadel     94.6         Alabama A&M      3.6
# no data             no data  no data             no data  no data
# no data             no data  no data             no data  no data
# no data             no data  no data             no data  no data
# no data             no data  no data             no data  no data
# no data             no data  no data             no data  no data
# no data             no data  no data             no data  no data
# no data             no data  no data             no data  no data
# no data             no data  no data             no data  no data
# no data             no data  no data             no data  no data
# no data             no data  no data             no data  no data
# no data             no data  no data             no data  no data
# no data             no data  no data             no data  no data
# no data             no data  no data             no data  no data
# no data             no data  no data             no data  no data
# no data             no data  no data             no data  no data
# no data             no data  no data             no data  no data
# no data             no data  no data             no data  no data
#
#                      APG team      APG             FTP team      FTP  \
# year
# 2017.0                   UCLA     21.4           Notre Dame       80
# 2017.0                 Purdue     18.3        Central Mich.     79.1
# 2017.0               Lipscomb     18.2            Villanova       79
# 2017.0         North Carolina     18.1         Oklahoma St.     78.9
# 2017.0                   Iowa     17.7               Mercer     78.2
# 2017.0               Canisius     17.7            Marquette     78.1
# 2017.0         William & Mary     17.5              Wofford       78
# 2017.0      Purdue Fort Wayne     17.5             Michigan     77.9
# 2017.0           Savannah St.     17.3          Wake Forest     77.8
# 2017.0              Creighton     17.1           Vanderbilt     77.7
# 2017.0            The Citadel       17           Valparaiso     77.5
# 2017.0                Oakland       17               Lehigh     77.2
# 2017.0                    TCU     16.9     South Dakota St.     77.1
# 2017.0               Richmond     16.9        Eastern Wash.       77
# 2017.0           Michigan St.     16.9      St. Bonaventure     76.9
# 2017.0                Wofford     16.7                 Iona     76.8
# 2017.0           Saint Mary's     16.6              Belmont     76.8
# 2017.0               Marshall     16.5             La Salle     76.6
# 2017.0         Louisiana Tech     16.5              Arizona     76.5
# 2017.0              Marquette     16.4  Fairleigh Dickinson     76.5
# 2017.0          West Virginia     16.4           Wright St.     76.4
# 2017.0            Wichita St.     16.3                 Duke     76.2
# 2017.0                 Kansas     16.2             Arkansas     76.1
# 2017.0        Army West Point     16.2              Oakland     76.1
# 2017.0                 Toledo     16.2                Brown     75.9
# 2017.0                    SMU     16.2         Oral Roberts     75.9
# 2017.0                   UNCW     16.1               Purdue     75.7
# 2017.0                Samford     16.1          Albany (NY)     75.7
# 2017.0           Morehead St.     16.1          The Citadel     75.7
# 2017.0                Belmont       16              Georgia     75.7
# ...                       ...      ...                  ...      ...
# 2017.0             Coppin St.     10.5                 Navy     64.1
# 2017.0        Ark.-Pine Bluff     10.4           Pepperdine     64.1
# 2017.0                McNeese     10.4      CSU Bakersfield       64
# 2017.0               Cal Poly     10.4         Arkansas St.     63.8
# 2017.0           Ga. Southern     10.4          Alabama St.     63.7
# 2017.0     Col. of Charleston     10.2        San Francisco     63.6
# 2017.0              Idaho St.     10.2     UC Santa Barbara     63.4
# 2017.0                   SIUE     10.2         Gardner-Webb     62.4
# 2017.0                    UNI      9.9              Rutgers     62.3
# 2017.0               Portland      9.8    Central Conn. St.       62
# 2017.0            Alabama St.      9.7             LMU (CA)     61.9
# 2017.0   St. Francis Brooklyn      9.3             American     61.8
# 2017.0                 Howard        9       Northern Colo.     60.4
# no data           Mass Lowell       16          Mass Lowell     73.5
# no data     Abilene Christian     14.1       Incarnate Word     69.4
# no data          Grand Canyon     13.6         Grand Canyon     66.5
# no data        Incarnate Word     12.5    Abilene Christian     66.2
# no data               no data  no data              no data  no data
# no data               no data  no data              no data  no data
# no data               no data  no data              no data  no data
# no data               no data  no data              no data  no data
# no data               no data  no data              no data  no data
# no data               no data  no data              no data  no data
# no data               no data  no data              no data  no data
# no data               no data  no data              no data  no data
# no data               no data  no data              no data  no data
# no data               no data  no data              no data  no data
# no data               no data  no data              no data  no data
# no data               no data  no data              no data  no data
# no data               no data  no data              no data  no data
#
#                     SCMG team     SCMG               RPI team      RPI  \
# year
# 2017.0                Gonzaga     21.1        North Carolina     0.668
# 2017.0            Wichita St.     18.6               Kentucky    0.658
# 2017.0          West Virginia     14.8                 Kansas    0.656
# 2017.0           Saint Mary's     14.6              Villanova    0.655
# 2017.0              Villanova     14.5                Arizona    0.652
# 2017.0                   UCLA     14.3                Gonzaga    0.649
# 2017.0                    SMU     14.3                 Oregon    0.648
# 2017.0         North Carolina     13.8                Florida    0.642
# 2017.0               Kentucky     13.4                 Baylor    0.641
# 2017.0                 Oregon     13.1                   Duke     0.64
# 2017.0             Cincinnati     12.9             Louisville    0.637
# 2017.0                Florida     11.4                 Butler    0.628
# 2017.0                 Purdue     11.3             Cincinnati    0.627
# 2017.0                Vermont     11.3                   UCLA    0.627
# 2017.0             Louisville     11.3            Florida St.    0.625
# 2017.0                 Kansas     11.3                    SMU    0.624
# 2017.0           N.C. Central     11.3           Saint Mary's    0.621
# 2017.0           Middle Tenn.     11.1                 Purdue    0.617
# 2017.0         New Mexico St.     10.8               Virginia    0.616
# 2017.0         Louisiana Tech     10.7          West Virginia    0.613
# 2017.0                   Duke     10.6               Iowa St.    0.612
# 2017.0                Arizona     10.6            Notre Dame     0.608
# 2017.0                   Utah     10.3              Michigan     0.608
# 2017.0              Princeton     10.2         South Carolina    0.606
# 2017.0                   FGCU     10.1              Minnesota    0.605
# 2017.0            Florida St.       10                    VCU    0.605
# 2017.0              Wisconsin       10                 Xavier    0.604
# 2017.0                   ETSU      9.8               Arkansas    0.601
# 2017.0                   UNCW      9.8            Wichita St.    0.599
# 2017.0               Virginia      9.7              Wisconsin    0.599
# ...                       ...      ...                    ...      ...
# 2017.0                  Maine    -10.3        Northern Ariz.      0.39
# 2017.0              Idaho St.    -10.4             Coppin St.    0.387
# 2017.0        Ark.-Pine Bluff    -10.7                    FIU    0.385
# 2017.0             Pepperdine    -11.3           North Texas     0.385
# 2017.0   St. Francis Brooklyn    -11.7                Howard     0.384
# 2017.0               N.C. A&T    -11.8              Idaho St.    0.377
# 2017.0          Western Caro.    -11.9         Southern Utah     0.375
# 2017.0             Coppin St.    -12.6            Alabama St.    0.372
# 2017.0               Longwood      -13              Longwood      0.37
# 2017.0            Chicago St.    -13.2     Central Conn. St.     0.365
# 2017.0       Mississippi Val.    -13.5        Ark.-Pine Bluff    0.364
# 2017.0           Presbyterian    -13.6          Presbyterian     0.363
# 2017.0            Alabama A&M      -16        Bethune-Cookman     0.36
# no data           Mass Lowell     -2.8  St. Francis Brooklyn     0.345
# no data          Grand Canyon      5.8           Florida A&M     0.332
# no data     Abilene Christian     -2.2              N.C. A&T     0.314
# no data        Incarnate Word     -3.7           Alabama A&M     0.313
# no data               no data  no data                no data  no data
# no data               no data  no data                no data  no data
# no data               no data  no data                no data  no data
# no data               no data  no data                no data  no data
# no data               no data  no data                no data  no data
# no data               no data  no data                no data  no data
# no data               no data  no data                no data  no data
# no data               no data  no data                no data  no data
# no data               no data  no data                no data  no data
# no data               no data  no data                no data  no data
# no data               no data  no data                no data  no data
# no data               no data  no data                no data  no data
# no data               no data  no data                no data  no data
#
#                           SOS team      SOS            ID team    ID
# year
# 2017.0              North Carolina    0.607  Abilene Christian  1101
# 2017.0          Vanderbilt (19-16)    0.606          Air Force  1102
# 2017.0           Louisville (25-9)    0.604              Akron  1103
# 2017.0               Baylor (26-8)    0.601            Alabama  1104
# 2017.0            Virginia (23-11)      0.6        Alabama A&M  1105
# 2017.0             Kentucky (32-6)    0.598        Alabama St.  1106
# 2017.0              Florida (27-9)    0.598        Albany (NY)  1107
# 2017.0              Xavier (24-14)    0.597             Alcorn  1108
# 2017.0                 Duke (28-9)    0.596       Alliant Intl  1109
# 2017.0               Butler (25-9)    0.596           American  1110
# 2017.0         Michigan St (20-15)    0.592    Appalachian St.  1111
# 2017.0          Pittsburgh (16-17)     0.59            Arizona  1112
# 2017.0            Nebraska (11-19)     0.59        Arizona St.  1113
# 2017.0               Kansas (31-5)     0.59        Little Rock  1114
# 2017.0         Oklahoma St (19-13)    0.588    Ark.-Pine Bluff  1115
# 2017.0             Iowa St (24-11)    0.588           Arkansas  1116
# 2017.0               Texas (11-22)    0.588       Arkansas St.  1117
# 2017.0             Georgia (18-15)    0.587      Armstrong St.  1118
# 2017.0            Michigan (26-12)    0.584    Army West Point  1119
# 2017.0              Arizona (32-5)    0.584             Auburn  1120
# 2017.0           Florida St (26-9)    0.582            Augusta  1121
# 2017.0           Minnesota (24-10)    0.582        Austin Peay  1122
# 2017.0      South Carolina (25-11)    0.581           Ball St.  1123
# 2017.0         Wake Forest (19-14)     0.58             Baylor  1124
# 2017.0            Illinois (19-15)     0.58            Belmont  1125
# 2017.0               Oregon (32-6)    0.579    Bethune-Cookman  1126
# 2017.0           Tennessee (15-16)    0.579         Binghamton  1127
# 2017.0          Notre Dame (26-10)    0.577      Birmingham So  1128
# 2017.0            Villanova (32-4)    0.576          Boise St.  1129
# 2017.0             Clemson (17-16)    0.575     Boston College  1130
# ...                            ...      ...                ...   ...
# 2017.0         Savannah St (11-16)    0.423         Vanderbilt  1435
# 2017.0      Ark.-Pine Bluff (6-24)     0.42            Vermont  1436
# 2017.0                 Alabama St.    0.419          Villanova  1437
# 2017.0   Cal St. Fullerton (15-15)    0.415           Virginia  1438
# 2017.0        LIU Brooklyn (19-12)    0.415      Virginia Tech  1439
# 2017.0    Central Conn. St. (6-23)    0.412                VMI  1440
# 2017.0          Delaware St (8-22)    0.412      Western Caro.  1441
# 2017.0             N.C. A&T (1-29)    0.411       Western Ill.  1442
# 2017.0            Southern (13-17)    0.399        Western Ky.  1443
# 2017.0        Jacksonville (13-16)    0.399      Western Mich.  1444
# 2017.0          Jackson St (12-17)    0.398        W Salem St.  1445
# 2017.0           Grambling (13-17)    0.395        W Texas A&M  1446
# 2017.0      Bethune-Cookman (8-22)    0.394             Wagner  1447
# no data         Alabama A&M (2-27)    0.391        Wake Forest  1448
# no data          Morgan St (13-16)    0.388         Washington  1449
# no data        N.C. Central (22-9)    0.387     Washington St.  1450
# no data         Florida A&M (5-23)    0.379          Weber St.  1451
# no data                    no data  no data      West Virginia  1452
# no data                    no data  no data          Green Bay  1453
# no data                    no data  no data          Milwaukee  1454
# no data                    no data  no data        Wichita St.  1455
# no data                    no data  no data     William & Mary  1456
# no data                    no data  no data           Winthrop  1457
# no data                    no data  no data          Wisconsin  1458
# no data                    no data  no data            Wofford  1459
# no data                    no data  no data         Wright St.  1460
# no data                    no data  no data            Wyoming  1461
# no data                    no data  no data             Xavier  1462
# no data                    no data  no data               Yale  1463
# no data                    no data  no data     Youngstown St.  1464
#
# [364 rows x 20 columns]

# %%
gd = pd.read_csv('games.csv')
gd.head()
# Out:
#    team A  team B  y  yr
# 0    1104    1157  1  17
# 1    1336    1107 -1  -6
# 2    1112    1277  1   2
# 3    1113    1340  1  18
# 4    1116    1236  1   9

# %% [markdown]
# # Collect Training Data (2017 season)

# %%
number_of_games = len(gd.index)
x1 = np.zeros(shape=(number_of_games,1))
y = gd['y'].values
year = 2017.0

for p in range(number_of_games):
    teamA_id = (gd.iloc[p])['team A']
    teamB_id = (gd.iloc[p])['team B']

    teamA = ((oo.loc[oo['ID'] == teamA_id])['ID team']).values[0]
    teamB = ((oo.loc[oo['ID'] == teamB_id])['ID team']).values[0]

    x_A = ((oo.loc[oo['RPI team'].str.rstrip() == teamA])['RPI']).values[0]
    x_B = ((oo.loc[oo['RPI team'].str.rstrip() == teamB])['RPI']).values[0]
    x1[p] = (x_A - x_B)

# %%
number_of_games = len(gd.index)
x2 = np.zeros(shape=(number_of_games,1))

for p in range(number_of_games):
    teamA_id = (gd.iloc[p])['team A']
    teamB_id = (gd.iloc[p])['team B']

    teamA = ((oo.loc[oo['ID'] == teamA_id])['ID team']).values[0]
    teamB = ((oo.loc[oo['ID'] == teamB_id])['ID team']).values[0]

    x_A = ((oo.loc[oo['SCMG team'].str.rstrip() == teamA])['SCMG']).values[0]
    x_B = ((oo.loc[oo['SCMG team'].str.rstrip() == teamB])['SCMG']).values[0]
    x2[p] = (x_A - x_B)

# %%
number_of_games = len(gd.index)
x3 = np.zeros(shape=(number_of_games,1))

for p in range(number_of_games):
    teamA_id = (gd.iloc[p])['team A']
    teamB_id = (gd.iloc[p])['team B']

    teamA = ((oo.loc[oo['ID'] == teamA_id])['ID team']).values[0]
    teamB = ((oo.loc[oo['ID'] == teamB_id])['ID team']).values[0]

    x_A = ((oo.loc[oo['FTP team'].str.rstrip() == teamA])['FTP']).values[0]
    x_B = ((oo.loc[oo['FTP team'].str.rstrip() == teamB])['FTP']).values[0]
    x3[p] = (x_A - x_B)

# %%
number_of_games = len(gd.index)
x4 = np.zeros(shape=(number_of_games,1))

for p in range(number_of_games):
    teamA_id = (gd.iloc[p])['team A']
    teamB_id = (gd.iloc[p])['team B']

    teamA = ((oo.loc[oo['ID'] == teamA_id])['ID team']).values[0]
    teamB = ((oo.loc[oo['ID'] == teamB_id])['ID team']).values[0]

    x_A = ((oo.loc[oo['APG team'].str.rstrip() == teamA])['APG']).values[0]
    x_B = ((oo.loc[oo['APG team'].str.rstrip() == teamB])['APG']).values[0]
    x4[p] = (x_A - x_B)

# %%
X = np.concatenate((np.ones(shape=(number_of_games,1)),x1,x2,x3,x4),axis=1)
y.shape = (number_of_games,1)

# %% [markdown]
# # Gradient Descent for soft-max classification

# %%
# run gradient descent
def gradient_descent(X,y,w0):
    w_path = []                 # container for weights learned at each iteration
    cost_path = []              # container for associated objective values at each iteration
    w_path.append(w0)
    cost = compute_cost(w0)
    cost_path.append(cost)
    w = w0
    # start gradient descent loop
    max_its = 20000
    alpha = 1e-5
    for k in range(max_its):
        grad = np.dot(X.T,r(w))
        # take gradient step
        w = w - alpha*grad
        # update path containers
        w_path.append(w)
        cost = compute_cost(w)
        cost_path.append(cost)


    return w_path,cost_path

# returns r vector defined for the gradient of a soft-max cost function, g2, for a given input weight w
def r(w):
    sig_minus = -(1/(1 + my_exp(y*np.dot(X,w))))
    r = y*sig_minus
    return r

# calculate the cost, g2, for a given input weight w
def compute_cost(w):
    sig_inv = (1 + my_exp(-y*np.dot(X,w)))
    log_sig_inv = np.log(sig_inv)
    g2 = np.sum(log_sig_inv)
    return g2

# avoid overflow when using exp - just cutoff after arguments get too large/small
def my_exp(u):
    s = np.argwhere(u > 100)
    t = np.argwhere(u < -100)
    u[s] = 0
    u[t] = 0
    u = np.exp(u)
    u[t] = 1
    return u

# %%
number_of_features = 4
w_init = np.zeros(shape=(number_of_features+1,1))
w_init[0] = 0 # expect b to be 0
w_init[1] =  0  # RPI weight
w_init[2] = 1 # Scoring Margin weight - guess that scoring margin is only important feature
w_init[3] = 0 # FTP weight
w_init[4] = 0 # APG weight

w,g2 = gradient_descent(X, y,w_init)

plt.plot(g2,color='r')
plt.xlim(0,100)
plt.xlabel('iteration',fontsize=14)
plt.ylabel('soft-max cost',fontsize=14)
plt.show()
print(g2[0])
print(g2[-1])
print(w[-1])
# Out:
# 7295.935807764299
# 2832.169837248108
# [[-1.96859155e-02]
#  [ 4.93763520e+00]
#  [ 1.17357946e-01]
#  [ 8.07023940e-03]
#  [ 3.60884792e-03]]

# %%
# best fit model parameters
b = -1.96859155e-02
w1 = 4.93763520
w2 = 1.17357946e-01
w3 = 8.07023940e-03
w4 = 3.60884792e-03
plt.scatter(b + w1*x1 + w2*x2 + w3*x3 + w4*x4,y,color='r',label='wins and losses')
plt.scatter(b + w1*x1 + w2*x2 + w3*x3 + w4*x4,np.tanh(b + w1*x1 + w2*x2 + w3*x3 + w4*x4),color='k',label='fit tanh() curve')
plt.yticks([-1,0,1],fontsize=12)
plt.xticks([-6,-4,-2,0,2,4,6],fontsize=12)
plt.legend()
plt.show()

# %% [markdown]
# # MSE linear regression

# %%
y = gd['yr'].values # get regression values
y.shape = (number_of_games,1)

fig = plt.figure(figsize = (15,5))
plt.subplot(1,4,1)
plt.scatter(x1,y)
plt.ylabel('game score margin',fontsize=14)
plt.xlabel('RPI',fontsize = 14)
plt.subplot(1,4,2)
plt.scatter(x2,y,color='r')
plt.xlabel('Avg. scoring margin',fontsize = 14)
plt.subplot(1,4,3)
plt.scatter(x3,y,color='m')
plt.xlabel('Free Throw %',fontsize = 14)
plt.subplot(1,4,4)
plt.scatter(x4,y,color='k')
plt.xlabel('Assists per game',fontsize = 14)
# Out:
# Text(0.5,0,'Assists per game')

# %%
def gradient_descent(X,y,w0):
    w_path = []                 # container for weights learned at each iteration
    cost_path = []              # container for associated objective values at each iteration
    w_path.append(w0)
    cost = compute_cost_linreg(w0)
    cost_path.append(cost)
    w = w0
    # start gradient descent loop
    max_its = 6000
    alpha = 1e-4
    for k in range(max_its):
        grad = np.dot(X.T,r_linreg(w))
        # take gradient step
        w = w - alpha*grad
        # update path containers
        w_path.append(w)
        cost = compute_cost_linreg(w)
        cost_path.append(cost)


    return w_path,cost_path

# routines for linear regression
def r_linreg(w):
    r = 2*(np.dot(X,w) - y)
    return r
def compute_cost_linreg(w):
    sqrs = np.square((np.dot(X,w) - y))
    g = np.sum(sqrs)
    return g

# %%
number_of_features = 1
w_init = np.zeros(shape=(number_of_features+1,1))
w_init[0] = 0 # expect b to be 0
w_init[1] =  0  # RPI weight

X = np.concatenate((np.ones(shape=(number_of_games,1)),x1),axis=1)

w,g = gradient_descent(X,y,w_init)

plt.plot(g,color='r')
plt.xlim(0,500)
plt.xlabel('iteration',fontsize=14)
plt.ylabel('MSE cost',fontsize=14)
plt.show()
print(g[0])
print(g[-1])
print(np.sqrt(g[-1] / len(y)))
print(w[-1])
# Out:
# 1254042.0
# 708865.0572323787
# 11.462677132745233
# [[-9.87993603e-02]
#  [ 1.23702854e+02]]

# %%
t = np.linspace(-0.3,0.3,len(y))
plt.scatter(x1,y)
plt.plot(t,-9.87993603e-02 + 1.23702854e+02*t,'k')
plt.show()

# %% [markdown]
# # Collect Test Data (2017 Tournament)

# %%
test_gd = pd.read_csv('tourney_games.csv')
test_gd.head()
# Out:
#           team A               team B  y  yr
# 0      Villanova       Mt. St. Mary's  1  20
# 1  Virginia Tech            Wisconsin -1 -10
# 2           UNCW             Virginia -1  -5
# 3        Florida                 ETSU  1  15
# 4            SMU  Southern California -1  -1

# %%
number_of_tourney_games = len(test_gd.index)
x1 = np.zeros(shape=(number_of_tourney_games,1))
y = test_gd['y'].values
year = 2017.0

for p in range(number_of_tourney_games):
    teamA = (test_gd.iloc[p])['team A'].strip()
    teamB = (test_gd.iloc[p])['team B'].strip()

    x_A = ((oo.loc[oo['RPI team'].str.rstrip() == teamA])['RPI']).values[0]
    x_B = ((oo.loc[oo['RPI team'].str.rstrip() == teamB])['RPI']).values[0]
    x1[p] = (x_A - x_B)

# %%
x2 = np.zeros(shape=(number_of_tourney_games,1))
for p in range(number_of_tourney_games):
    teamA = (test_gd.iloc[p])['team A'].strip()
    teamB = (test_gd.iloc[p])['team B'].strip()

    x_A = ((oo.loc[oo['SCMG team'].str.rstrip() == teamA])['SCMG']).values[0]
    x_B = ((oo.loc[oo['SCMG team'].str.rstrip() == teamB])['SCMG']).values[0]
    x2[p] = (x_A - x_B)

# %%
x3 = np.zeros(shape=(number_of_tourney_games,1))
for p in range(number_of_tourney_games):
    teamA = (test_gd.iloc[p])['team A'].strip()
    teamB = (test_gd.iloc[p])['team B'].strip()

    x_A = ((oo.loc[oo['FTP team'].str.rstrip() == teamA])['FTP']).values[0]
    x_B = ((oo.loc[oo['FTP team'].str.rstrip() == teamB])['FTP']).values[0]
    x3[p] = (x_A - x_B)

# %%
x4 = np.zeros(shape=(number_of_tourney_games,1))
for p in range(number_of_tourney_games):
    teamA = (test_gd.iloc[p])['team A'].strip()
    teamB = (test_gd.iloc[p])['team B'].strip()

    x_A = ((oo.loc[oo['APG team'].str.rstrip() == teamA])['APG']).values[0]
    x_B = ((oo.loc[oo['APG team'].str.rstrip() == teamB])['APG']).values[0]
    x4[p] = (x_A - x_B)

# %% [markdown]
# # Calculate number of missclassifications in test

# %%
b = -1.96859155e-02
w1 = 4.93763520
w2 = 1.17357946e-01
w3 = 8.07023940e-03
w4 = 3.60884792e-03

number_of_round1_games = 32
y.shape = (number_of_tourney_games,1)
y_expect = np.zeros(shape=(number_of_tourney_games,1))
miss_classifications = 0
for p in range(number_of_round1_games):
    classifier = b + w1*x1[p] + w2*x2[p] + w3*x3[p] + w4*x4[p]
    if classifier > 0:
        y_expect[p] = 1
    else:
        y_expect[p] = -1
    if y_expect[p] != y[p]:
        miss_classifications += 1
        
success_percentage = (1 - (miss_classifications/number_of_round1_games))*100

print('predicted {}% of 1st round games correctly'.format(success_percentage))
Y = np.concatenate((y,y_expect),axis=1)
# Out:
# predicted 84.375% of 1st round games correctly

# %% [markdown]
# # Compare actual scores to predicted score (from RPI regression)

# %%
b = -9.87993603e-02
w1 = 1.23702854e+02

number_of_round1_games = 32
y = test_gd['yr'].values
y.shape = (number_of_tourney_games,1)
y_expect = np.zeros(shape=(number_of_tourney_games,1))

for p in range(number_of_round1_games):
    score_margin_prediction = b + w1*x1[p]
    y_expect[p] = score_margin_prediction
# success_percentage = (1 - (miss_classifications/number_of_round1_games))*100 
# print('predicted {}% of 1st round games correctly'.format(success_percentage))
Y = np.concatenate((y,y_expect),axis=1)
plt.plot(y,label='actual score margin',color='k')
plt.plot(y_expect,label='predicted score margin',color='r')
plt.xlim(0,32)
plt.legend()
plt.show()
